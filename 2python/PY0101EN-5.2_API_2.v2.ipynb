# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Simple APIs
# ## Random User and Fruitvice API Examples
#
#
# Estimated time needed: **25** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Load and use RandomUser API, using `RandomUser()` Python library
# *   Load and use Fruitvice API, using `requests` Python library

# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned from previous videos and notebooks, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#  *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more
#      productive.
#  *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#      independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#  *   **Secirity**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data
#      breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruitvice application. The Fruitvice API webservice which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The webservice is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01) page.

# %% [markdown]
# ## **Get Methods**
#
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# Out:
# Requirement already satisfied: randomuser in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (1.6)

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x7f264e81c690>,
#  <randomuser.RandomUser at 0x7f264e81c6d0>,
#  <randomuser.RandomUser at 0x7f264e81c710>,
#  <randomuser.RandomUser at 0x7f264e81c750>,
#  <randomuser.RandomUser at 0x7f264e81c790>,
#  <randomuser.RandomUser at 0x7f264e81c810>,
#  <randomuser.RandomUser at 0x7f264e81c850>,
#  <randomuser.RandomUser at 0x7f264e81c890>,
#  <randomuser.RandomUser at 0x7f264e81c8d0>,
#  <randomuser.RandomUser at 0x7f264e81c7d0>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Villads Pedersen   villads.pedersen@example.com
# Gene Ramos   gene.ramos@example.com
# Harper Wang   harper.wang@example.com
# Nathaniel Anderson   nathaniel.anderson@example.com
# Mehmet Karabulut   mehmet.karabulut@example.com
# Oya Koç   oya.koc@example.com
# Peter Young   peter.young@example.com
# Kaspar Laurent   kaspar.laurent@example.com
# Jade Martin   jade.martin@example.com
# Jessika Friesen   jessika.friesen@example.com

# %% [markdown]
# ## Exercise 1
# In this Exercise, generate photos of the random 5 users.

# %%
## Write your code here
for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/71.jpg
# https://randomuser.me/api/portraits/men/8.jpg
# https://randomuser.me/api/portraits/women/10.jpg
# https://randomuser.me/api/portraits/men/77.jpg
# https://randomuser.me/api/portraits/men/30.jpg
# https://randomuser.me/api/portraits/women/5.jpg
# https://randomuser.me/api/portraits/men/48.jpg
# https://randomuser.me/api/portraits/men/10.jpg
# https://randomuser.me/api/portraits/women/18.jpg
# https://randomuser.me/api/portraits/women/54.jpg

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                Name  Gender             City             State  \
# 0   آدرینا كامياران  female          نیشابور             قزوین
# 1    Ludvik Oppedal    male          Holmsbu  Sogn og Fjordane
# 2      بهار نكو نظر  female            گرگان               یزد
# 3    Freja Pedersen  female  Kongens  Lyngby       Hovedstaden
# 4  Sophie Fernandez  female    Rothenbrunnen        St. Gallen
# 5          Emma Flo  female         Åkrehamn         Hordaland
# 6     Tilje Helstad  female           Strand          Vestfold
# 7        Sofia King  female         Hastings             Otago
# 8    Roope Lehtonen    male        Outokumpu         Satakunta
# 9      Leon Olivier    male       Bonvillars            Glarus
#
#                           Email                       DOB  \
# 0       adryn.kmyrn@example.com  1964-02-27T14:55:20.135Z
# 1    ludvik.oppedal@example.com  1975-02-08T00:33:43.904Z
# 2        bhr.nkwnzr@example.com  1991-12-13T11:33:10.853Z
# 3    freja.pedersen@example.com  1952-02-19T16:37:21.195Z
# 4  sophie.fernandez@example.com  1986-04-19T16:40:55.620Z
# 5          emma.flo@example.com  1996-02-13T21:32:18.119Z
# 6     tilje.helstad@example.com  1965-01-16T08:54:41.307Z
# 7        sofia.king@example.com  1967-02-11T02:53:33.943Z
# 8    roope.lehtonen@example.com  1977-10-05T09:02:07.044Z
# 9      leon.olivier@example.com  1969-12-07T18:19:00.234Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/52.jpg
# 1    https://randomuser.me/api/portraits/men/47.jpg
# 2  https://randomuser.me/api/portraits/women/79.jpg
# 3  https://randomuser.me/api/portraits/women/81.jpg
# 4  https://randomuser.me/api/portraits/women/71.jpg
# 5   https://randomuser.me/api/portraits/women/9.jpg
# 6  https://randomuser.me/api/portraits/women/85.jpg
# 7  https://randomuser.me/api/portraits/women/30.jpg
# 8    https://randomuser.me/api/portraits/men/32.jpg
# 9    https://randomuser.me/api/portraits/men/48.jpg

# %%
df1 = pd.DataFrame(get_users())

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruitvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruitvice](https://www.fruityvice.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://www.fruityvice.com/api/fruit/all")
# Out:
# ---------------------------------------------------------------------------
# CertificateError                          Traceback (most recent call last)
# ~/conda/envs/python/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#
# ~/conda/envs/python/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# ~/conda/envs/python/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#
# ~/conda/envs/python/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     466                 )
# --> 467             _match_hostname(cert, self.assert_hostname or server_hostname)
#     468
#
# ~/conda/envs/python/lib/python3.7/site-packages/urllib3/connection.py in _match_hostname(cert, asserted_hostname)
#     539     try:
# --> 540         match_hostname(cert, asserted_hostname)
#     541     except CertificateError as e:
#
# ~/conda/envs/python/lib/python3.7/site-packages/urllib3/util/ssl_match_hostname.py in match_hostname(cert, hostname)
#     151             "hostname %r "
# --> 152             "doesn't match either of %s" % (hostname, ", ".join(map(repr, dnsnames)))
#     153         )
#
# CertificateError: hostname 'www.fruityvice.com' doesn't match either of 'fruityvice.com', 'sonarqube.fruityvice.com'
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/conda/envs/python/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     498                     retries=self.max_retries,
# --> 499                     timeout=timeout,
#     500                 )
#
# ~/conda/envs/python/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     787             retries = retries.increment(
# --> 788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789             )
#
# ~/conda/envs/python/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='www.fruityvice.com', port=443): Max retries exceeded with url: /api/fruit/all (Caused by SSLError(CertificateError("hostname 'www.fruityvice.com' doesn't match either of 'fruityvice.com', 'sonarqube.fruityvice.com'")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /tmp/ipykernel_423/3601050008.py in <module>
# ----> 1 data = requests.get("https://www.fruityvice.com/api/fruit/all")
#
# ~/conda/envs/python/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/conda/envs/python/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/conda/envs/python/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/conda/envs/python/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/conda/envs/python/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     561             if isinstance(e.reason, _SSLError):
#     562                 # This branch is for urllib3 v1.22 and later.
# --> 563                 raise SSLError(e, request=request)
#     564
#     565             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.fruityvice.com', port=443): Max retries exceeded with url: /api/fruit/all (Caused by SSLError(CertificateError("hostname 'www.fruityvice.com' doesn't match either of 'fruityvice.com', 'sonarqube.fruityvice.com'")))

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_423/755625042.py in <module>
# ----> 1 results = json.loads(data.text)
#
# NameError: name 'data' is not defined

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Theobroma     Chocolate  88        Malvaceae          Malvales
# 8      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 9   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 10         Durio        Durian  60        Malvaceae          Malvales
# 11    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 12         Ficus           Fig  68         Moraceae           Rosales
# 13         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 14         Vitis         Grape  81         Vitaceae           Vitales
# 15         Vitis        Grapes  47         Vitaceae           Vitales
# 16         Malus    GreenApple  72         Rosaceae           Rosales
# 17       Psidium         Guava  37        Myrtaceae          Myrtales
# 18       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 19     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 20        Citrus         Lemon  26         Rutaceae        Sapindales
# 21        Citrus          Lime  44         Rutaceae        Sapindales
# 22     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 23        Litchi        Lychee  67      Sapindaceae        Sapindales
# 24     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 25       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 26         Morus         Morus  82         Moraceae           Rosales
# 27        Citrus        Orange   2         Rutaceae        Sapindales
# 28        Carica        Papaya  42       Caricaceae         Caricacea
# 29    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 30        Prunus         Peach  86         Rosaceae           Rosales
# 31         Pyrus          Pear   4         Rosaceae           Rosales
# 32     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 33        Ananas     Pineapple  10     Bromeliaceae            Poales
# 34     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 35        Prunus          Plum  71         Rosaceae           Rosales
# 36        Punica   Pomegranate  79       Lythraceae          Myrtales
# 37         Rubus     Raspberry  23         Rosaceae           Rosales
# 38      Fragaria    Strawberry   3         Rosaceae           Rosales
# 39        Citrus     Tangerine  77         Rutaceae        Sapindales
# 40       Solanum        Tomato   5       Solanaceae         Solanales
# 41     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#                                            nutritions
# 0   {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1   {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2   {'carbohydrates': 8.53, 'protein': 2, 'fat': 1...
# 3   {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 4   {'carbohydrates': 9, 'protein': 1.3, 'fat': 0....
# 5   {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 6   {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 7   {'carbohydrates': 58, 'protein': 8.51, 'fat': ...
# 8   {'carbohydrates': 12.2, 'protein': 0.4, 'fat':...
# 9   {'carbohydrates': 9, 'protein': 9, 'fat': 1.5,...
# 10  {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# 11  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....
# 12  {'carbohydrates': 19, 'protein': 0.8, 'fat': 0...
# 13  {'carbohydrates': 10, 'protein': 0.9, 'fat': 0...
# 14  {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 15  {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 16  {'carbohydrates': 3.1, 'protein': 0.4, 'fat': ...
# 17  {'carbohydrates': 14, 'protein': 2.6, 'fat': 1...
# 18  {'carbohydrates': 15, 'protein': 1.1, 'fat': 0...
# 19  {'carbohydrates': 14.6, 'protein': 1.14, 'fat'...
# 20  {'carbohydrates': 9, 'protein': 1.1, 'fat': 0....
# 21  {'carbohydrates': 8.4, 'protein': 0.3, 'fat': ...
# 22  {'carbohydrates': 11.3, 'protein': 0.75, 'fat'...
# 23  {'carbohydrates': 17, 'protein': 0.8, 'fat': 0...
# 24  {'carbohydrates': 15, 'protein': 0.82, 'fat': ...
# 25  {'carbohydrates': 8, 'protein': 0, 'fat': 0, '...
# 26  {'carbohydrates': 9.8, 'protein': 1.44, 'fat':...
# 27  {'carbohydrates': 8.3, 'protein': 1, 'fat': 0....
# 28  {'carbohydrates': 11, 'protein': 0, 'fat': 0.4...
# 29  {'carbohydrates': 22.4, 'protein': 2.2, 'fat':...
# 30  {'carbohydrates': 9.5, 'protein': 0.9, 'fat': ...
# 31  {'carbohydrates': 15, 'protein': 0.4, 'fat': 0...
# 32  {'carbohydrates': 18, 'protein': 0, 'fat': 0, ...
# 33  {'carbohydrates': 13.12, 'protein': 0.54, 'fat...
# 34  {'carbohydrates': 7, 'protein': 1, 'fat': 0.4,...
# 35  {'carbohydrates': 11.4, 'protein': 0.7, 'fat':...
# 36  {'carbohydrates': 18.7, 'protein': 1.7, 'fat':...
# 37  {'carbohydrates': 12, 'protein': 1.2, 'fat': 0...
# 38  {'carbohydrates': 5.5, 'protein': 0.8, 'fat': ...
# 39  {'carbohydrates': 8.3, 'protein': 0, 'fat': 0....
# 40  {'carbohydrates': 3.9, 'protein': 0.9, 'fat': ...
# 41  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Theobroma     Chocolate  88        Malvaceae          Malvales
# 8      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 9   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 10         Durio        Durian  60        Malvaceae          Malvales
# 11    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 12         Ficus           Fig  68         Moraceae           Rosales
# 13         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 14         Vitis         Grape  81         Vitaceae           Vitales
# 15         Vitis        Grapes  47         Vitaceae           Vitales
# 16         Malus    GreenApple  72         Rosaceae           Rosales
# 17       Psidium         Guava  37        Myrtaceae          Myrtales
# 18       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 19     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 20        Citrus         Lemon  26         Rutaceae        Sapindales
# 21        Citrus          Lime  44         Rutaceae        Sapindales
# 22     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 23        Litchi        Lychee  67      Sapindaceae        Sapindales
# 24     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 25       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 26         Morus         Morus  82         Moraceae           Rosales
# 27        Citrus        Orange   2         Rutaceae        Sapindales
# 28        Carica        Papaya  42       Caricaceae         Caricacea
# 29    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 30        Prunus         Peach  86         Rosaceae           Rosales
# 31         Pyrus          Pear   4         Rosaceae           Rosales
# 32     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 33        Ananas     Pineapple  10     Bromeliaceae            Poales
# 34     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 35        Prunus          Plum  71         Rosaceae           Rosales
# 36        Punica   Pomegranate  79       Lythraceae          Myrtales
# 37         Rubus     Raspberry  23         Rosaceae           Rosales
# 38      Fragaria    Strawberry   3         Rosaceae           Rosales
# 39        Citrus     Tangerine  77         Rutaceae        Sapindales
# 40       Solanum        Tomato   5       Solanaceae         Solanales
# 41     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#     nutritions.carbohydrates  nutritions.protein  nutritions.fat  \
# 0                      11.40                0.30            0.40
# 1                       3.90                0.50            0.10
# 2                       8.53                2.00           14.66
# 3                      22.00                1.00            0.20
# 4                       9.00                1.30            0.40
# 5                       5.50                0.00            0.40
# 6                      12.00                1.00            0.30
# 7                      58.00                8.51           30.57
# 8                      12.20                0.40            0.10
# 9                       9.00                9.00            1.50
# 10                     27.10                1.50            5.30
# 11                      8.00                0.60            0.40
# 12                     19.00                0.80            0.30
# 13                     10.00                0.90            0.60
# 14                     18.10                0.72            0.16
# 15                     18.10                0.72            0.16
# 16                      3.10                0.40            0.10
# 17                     14.00                2.60            1.00
# 18                     15.00                1.10            0.50
# 19                     14.60                1.14            0.50
# 20                      9.00                1.10            0.30
# 21                      8.40                0.30            0.10
# 22                     11.30                0.75            0.34
# 23                     17.00                0.80            0.44
# 24                     15.00                0.82            0.38
# 25                      8.00                0.00            0.00
# 26                      9.80                1.44            0.39
# 27                      8.30                1.00            0.20
# 28                     11.00                0.00            0.40
# 29                     22.40                2.20            0.70
# 30                      9.50                0.90            0.25
# 31                     15.00                0.40            0.10
# 32                     18.00                0.00            0.00
# 33                     13.12                0.54            0.12
# 34                      7.00                1.00            0.40
# 35                     11.40                0.70            0.28
# 36                     18.70                1.70            1.20
# 37                     12.00                1.20            0.70
# 38                      5.50                0.80            0.40
# 39                      8.30                0.00            0.40
# 40                      3.90                0.90            0.20
# 41                      8.00                0.60            0.20
#
#     nutritions.calories  nutritions.sugar
# 0                    52             10.30
# 1                    15              3.20
# 2                   160              0.66
# 3                    96             17.20
# 4                    40              4.50
# 5                    29              5.40
# 6                    50              8.00
# 7                   531             54.00
# 8                    46              4.00
# 9                    60              8.00
# 10                  147              6.75
# 11                   44              3.00
# 12                   74             16.00
# 13                   44              0.00
# 14                   69             16.00
# 15                   69             15.48
# 16                   21              6.40
# 17                   68              9.00
# 18                   61              9.00
# 19                   61              8.90
# 20                   29              2.50
# 21                   25              1.70
# 22                   50              5.74
# 23                   66             15.00
# 24                   60             13.70
# 25                   34              8.00
# 26                   43              8.10
# 27                   43              8.20
# 28                   43              1.00
# 29                   97             11.20
# 30                   39              8.40
# 31                   57             10.00
# 32                   81             18.00
# 33                   50              9.85
# 34                   36              3.00
# 35                   46              9.92
# 36                   83             13.70
# 37                   53              4.40
# 38                   29              5.40
# 39                   45              9.10
# 40                   74              2.60
# 41                   30              6.00

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here
cal_banana = df2.loc[df2["name"] == 'Banana']
cal_banana.iloc[0]['nutritions.calories']
# Out:
# 96

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://github.com/public-apis/public-apis#animals) contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
# 1. Using `requests.get("url")` function, load your data.

# %%
# Write your code here
data2=requests.get("https://www.fishwatch.gov/api/species")
data2
# Out:
# <Response [200]>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://www.fishwatch.gov/api/species")
# ```
#
# </details>

# %% [markdown]
# 2. Retrieve results using `json.loads()` function.

# %%
# Write your code here
results = json.loads(data2.text)
results

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3. Convert json data into *pandas* data frame.

# %%
# Write your code here
df3 = pd.DataFrame(results)
df3

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3
# ```
#
# </details>

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Author
# [Svitlana Kramar](www.linkedin.com/in/svitlana-kramar)
#
#
# Svitlana is a master’s degree Data Science and Analytics student at University of Calgary, who enjoys travelling, learning new languages and cultures and loves spreading her passion for Data Science.

# %% [markdown]
#                                 Copyright © 2020 IBM Corporation. All rights reserved.
